# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


data=pd.read_csv('/home/abhishek/Downloads/data.csv')
data.head()
data['id'] = data['id'].astype('category').cat.codes
data['diagnosis'] = data['diagnosis'].astype('category').cat.codes
data.head()
# Out:
#     id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   41          1        17.99         10.38          122.80     1001.0
# 1   42          1        20.57         17.77          132.90     1326.0
# 2  488          1        19.69         21.25          130.00     1203.0
# 3  489          1        11.42         20.38           77.58      386.1
# 4  490          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#       ...       texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
plt.scatter(data['id'],data['radius_mean'])
plt.show()
sns.distplot(data['radius_mean'])
sns.plt.show()
data['radius_mean'].hist()
plt.show()

# %%
corr=data.corr()
corr
# Out:
#                                id  diagnosis  radius_mean  texture_mean  \
# id                       1.000000  -0.079866     0.051988      0.174081
# diagnosis               -0.079866   1.000000     0.730029      0.415185
# radius_mean              0.051988   0.730029     1.000000      0.323782
# texture_mean             0.174081   0.415185     0.323782      1.000000
# perimeter_mean           0.049730   0.742636     0.997855      0.329533
# area_mean                0.053038   0.708984     0.987357      0.321086
# smoothness_mean         -0.067243   0.358560     0.170581     -0.023389
# compactness_mean        -0.007802   0.596534     0.506124      0.236702
# concavity_mean          -0.006799   0.696360     0.676764      0.302418
# concave points_mean      0.001784   0.776614     0.822529      0.293464
# symmetry_mean           -0.013024   0.330499     0.147741      0.071401
# fractal_dimension_mean  -0.073221  -0.012838    -0.311631     -0.076437
# ...

# %%
features_space = list(data.columns[1:11])
plt.figure(figsize=(14,14))

corr=data[features_space].corr()
sns.heatmap(corr, cbar = True,  square = True, annot=True, fmt= '.2f',annot_kws={'size': 15},cmap='coolwarm')
sns.plt.show()
